# %%
run parseInput.py

# %%
run ClumpingModule.py

# %%
run M1EAModule.py

# %%
run OrbiM1Module.py

# %%
run M2Module.py

# %%
run predictMeasurement.py

# %%
inputFile = parseInput('C2NO2ExampleClumpM1.csv')
df = pd.DataFrame.from_dict(inputFile['basicInfo'])

# %%
df
# Out:
#   atom ID element  Stoich  Equivalence   70   54   42  Ref Deltas
# 0     C-1       C     1.0          0.0  1.0  1.0  0.0        25.0
# 1     C-2       C     1.0          0.0  1.0  1.0  1.0       -25.0
# 2     N-3       N     1.0          0.0  1.0  1.0  1.0         0.0
# 3     O-4       O     1.0          0.0  1.0  1.0  1.0        25.0
# 4     O-5       O     1.0          0.0  1.0  0.0  0.0       -25.0

# %%
#pd.set_option('precision', 15)
#generateExpectedM1Measurements(df, inputFile['M1Dict']['Fragment List'])

# %%
#generateExpectedM2Measurements(df, inputFile)

# %%
solution = computeOValuesWithUncertainty(inputFile,notResolved = [], N=1)
df2 = processOrbiM1Results(df, solution)
# Out:
# System is constrained, you're good to go

# %% [markdown]
# Not accounting for the clumps immediately introduces error into our M1 experiment

# %%
df2
# Out:
#   atom ID element  Stoich  Equivalence   70   54   42  Ref Deltas  \
# 0     C-1       C     1.0          0.0  1.0  1.0  0.0        25.0
# 1     C-2       C     1.0          0.0  1.0  1.0  1.0       -25.0
# 2     N-3       N     1.0          0.0  1.0  1.0  1.0         0.0
# 3     O-4       O     1.0          0.0  1.0  1.0  1.0        25.0
# 4     O-5       O     1.0          0.0  1.0  0.0  0.0       -25.0
#
#    Fractional Abundance  Fractional Abundance Error  O Values  O Error  \
# 0              0.427993                         0.0  0.011513      0.0
# 1              0.407490                         0.0  0.010961      0.0
# 2              0.136271                         0.0  0.003666      0.0
# 3              0.014476                         0.0  0.000389      0.0
# 4              0.013770                         0.0  0.000370      0.0
#
#      Ratios  Ratios Error     Deltas  Deltas Error
# 0  0.011513           0.0  24.535851           0.0
# 1  0.010961           0.0 -24.546174           0.0
# 2  0.003666           0.0  -2.810664           0.0
# 3  0.000389           0.0  24.994612           0.0
# 4  0.000370           0.0 -25.005141           0.0

# %%
M2Output = dataFrameToM2Matrix(df, inputFile, measurement = True)
sol = solveByGaussianElimination(M2Output)
M2Solution = sol[0]
findM2Gamma(M2Solution,inputFile, '18O')
computeM2ORValues(M2Solution)
# Out:
# Found site-specific ratios, ignoring reference deltas
#                          Types Composition  M2 Percent Abundance  \
# 13C C-1   |   13C C-2  Clumped     13C/13C              0.028518
# 13C C-1   |   15N N-3  Clumped     13C/15N              0.012405
# 13C C-1   |   17O O-4  Clumped     13C/17O              0.001057
# 13C C-1   |   17O O-5  Clumped     13C/17O              0.001005
# 13C C-2   |   15N N-3  Clumped     13C/15N              0.009489
# 13C C-2   |   17O O-4  Clumped     13C/17O              0.001005
# 13C C-2   |   17O O-5  Clumped     13C/17O              0.000956
# 15N N-3   |   17O O-4  Clumped     15N/17O              0.000337
# 15N N-3   |   17O O-5  Clumped     15N/17O              0.000321
# 17O O-4   |   17O O-5  Clumped     17O/17O              0.000034
# 18O O-4                      O         18O              0.478578
# 18O O-5                      O         18O              0.466295
#
#                          Stochastic  M2 gamma     OR Values   Deltas  \
# 13C C-1   |   13C C-2  1.261973e-04  0.004244  1.210388e-04      N/A
# 13C C-1   |   15N N-3  4.220252e-05  0.004244  5.265298e-05      N/A
# 13C C-1   |   17O O-4  4.483076e-06  0.004244  4.485108e-06      N/A
# 13C C-1   |   17O O-5  4.264390e-06  0.004244  4.266319e-06      N/A
# 13C C-2   |   15N N-3  4.018074e-05  0.004244  4.027504e-05      N/A
# 13C C-2   |   17O O-4  4.268308e-06  0.004244  4.266324e-06      N/A
# 13C C-2   |   17O O-5  4.060097e-06  0.004244  4.058210e-06      N/A
# 15N N-3   |   17O O-4  1.427394e-06  0.004244  1.431419e-06      N/A
# 15N N-3   |   17O O-5  1.357765e-06  0.004244  1.361590e-06      N/A
# 17O O-4   |   17O O-5  1.442323e-07  0.004244  1.442331e-07      N/A
# 18O O-4                2.101583e-03  0.004244  2.031257e-03  12.9947
# 18O O-5                1.908776e-03  0.004244  1.979122e-03 -13.0052
#
#                       Clumped Deltas
# 13C C-1   |   13C C-2       -40.8765
# 13C C-1   |   15N N-3        247.627
# 13C C-1   |   17O O-4       0.453057
# 13C C-1   |   17O O-5       0.452491
# 13C C-2   |   15N N-3        2.34676
# 13C C-2   |   17O O-4       -0.46481
# 13C C-2   |   17O O-5       -0.46487
# 15N N-3   |   17O O-4        2.81921
# 15N N-3   |   17O O-5        2.81709
# 17O O-4   |   17O O-5     0.00549738
# 18O O-4                          N/A
# 18O O-5                          N/A

# %% [markdown]
# This causes us to miss on the clumped deltas by up to several per mil

# %%
sol = OValuesToRValues(df2, targetArray, clumpDict)

# %%
M2Output = dataFrameToM2Matrix(df, inputFile, measurement = True)
sol = solveByGaussianElimination(M2Output)
M2Solution = sol[0]
findM2Gamma(M2Solution,inputFile, '18O')
computeM2ORValues(M2Solution)
# Out:
# Found site-specific ratios, ignoring reference deltas
#                          Types Composition  M2 Percent Abundance  \
# 13C C-1   |   13C C-2  Clumped     13C/13C              0.028518
# 13C C-1   |   15N N-3  Clumped     13C/15N              0.012405
# 13C C-1   |   17O O-4  Clumped     13C/17O              0.001057
# 13C C-1   |   17O O-5  Clumped     13C/17O              0.001005
# 13C C-2   |   15N N-3  Clumped     13C/15N              0.009489
# 13C C-2   |   17O O-4  Clumped     13C/17O              0.001005
# 13C C-2   |   17O O-5  Clumped     13C/17O              0.000956
# 15N N-3   |   17O O-4  Clumped     15N/17O              0.000337
# 15N N-3   |   17O O-5  Clumped     15N/17O              0.000321
# 17O O-4   |   17O O-5  Clumped     17O/17O              0.000034
# 18O O-4                      O         18O              0.478578
# 18O O-5                      O         18O              0.466295
#
#                          Stochastic  M2 gamma     OR Values   Deltas  \
# 13C C-1   |   13C C-2  1.261957e-04  0.004244  1.210388e-04      N/A
# 13C C-1   |   15N N-3  4.234064e-05  0.004244  5.265298e-05      N/A
# 13C C-1   |   17O O-4  4.485131e-06  0.004244  4.485108e-06      N/A
# 13C C-1   |   17O O-5  4.266344e-06  0.004244  4.266319e-06      N/A
# 13C C-2   |   15N N-3  4.027524e-05  0.004244  4.027504e-05      N/A
# 13C C-2   |   17O O-4  4.266344e-06  0.004244  4.266324e-06      N/A
# 13C C-2   |   17O O-5  4.058229e-06  0.004244  4.058210e-06      N/A
# 15N N-3   |   17O O-4  1.431425e-06  0.004244  1.431419e-06      N/A
# 15N N-3   |   17O O-5  1.361599e-06  0.004244  1.361590e-06      N/A
# 17O O-4   |   17O O-5  1.442338e-07  0.004244  1.442331e-07      N/A
# 18O O-4                2.101603e-03  0.004244  2.031257e-03  12.9947
# 18O O-5                1.908796e-03  0.004244  1.979122e-03 -13.0052
#
#                       Clumped Deltas
# 13C C-1   |   13C C-2       -40.8646
# 13C C-1   |   15N N-3        243.557
# 13C C-1   |   17O O-4     -0.0051376
# 13C C-1   |   17O O-5    -0.00570519
# 13C C-2   |   15N N-3    -0.00511735
# 13C C-2   |   17O O-4    -0.00472503
# 13C C-2   |   17O O-5    -0.00478679
# 15N N-3   |   17O O-4    -0.00441768
# 15N N-3   |   17O O-5    -0.00653172
# 17O O-4   |   17O O-5    -0.00483881
# 18O O-4                          N/A
# 18O O-5                          N/A

# %% [markdown]
# For next time: turn this into an explicit iterator, and come up with some "stop" condition. The best one will look at the clumped anamolies and see if they fall within a certain range; i.e. the clumped anamolies from the O Value M1 experiment and compare to Stochastic - OR from this dataFrame.

# %% [markdown]
# Each iteration, the only thing that is changing is stochastic inside of the M2 dataFrame. So I think we can just check that no new clumps greater than the threshold have appeared and be good.

# %%
x = M1M2Iterator(inputFile,threshold = 0.05)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-488ac8a42029> in <module>
# ----> 1 x = M1M2Iterator(inputFile,threshold = 0.05)
#
# ~\Documents\Orbitrap Solver Experiment\Methionine-Computation-main\Methionine-Computation-main\M2Module.py in M1M2Iterator(inputFile, threshold)
#     670     #Solve M1
#     671     M1Input = pd.DataFrame.from_dict(inputFile['basicInfo'])
# --> 672     solution = computeOValuesWithUncertainty(inputFile,notResolved = [], N=1)
#     673     M1dataFrame = processOrbiM1Results(M1Input, solution)
#     674
#
# NameError: name 'computeOValuesWithUncertainty' is not defined
